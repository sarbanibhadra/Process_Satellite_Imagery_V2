# %%
import ee
import datetime

# Initialize Earth Engine
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# Define the Amazon Basin polygon
# Load the shapefile as an Earth Engine feature collection
amazon_basin = ee.FeatureCollection("projects/test-project-agb/assets/AmazonBasinLimits-master")

# GEDI L4A Collection
# Load GEDI Level 4A data
gedi_all = ee.FeatureCollection('LARSE/GEDI/GEDI04_A_002_INDEX')\
        .filter('time_start > "2022-03-01" && time_end < "2022-05-31"')\
        .filterBounds(amazon_basin);

# Get the list of table_id values
table_ids = gedi_all.aggregate_array('table_id').getInfo()

print("lenght of table id", len(table_ids))

# Initialize an empty FeatureCollection
gedi = ee.FeatureCollection([])

# Loop through each table ID and merge them
for table_id in table_ids:
    table = ee.FeatureCollection(table_id).filterBounds(amazon_basin);
    gedi = gedi.merge(table)


print("Check 1" )
# Step 1: Remove invalid AGBD measurements based on 'l4_quality_flag'
gedi_quality = gedi.filter(ee.Filter.eq('l4_quality_flag', 1))
print("check2")
# Step 2: Remove unreliable measurements with relative standard error > 50%
gedi_reliable = gedi_quality.filter(ee.Filter.lt('(agbd_se / agbd) * 100', 10))

print("check2", gedi_reliable.size().getInfo() )
# Step 3: Remove measurements on slopes > 30 degrees
# Load GLO-30 DEM
# srtm = ee.Image('projects/sat-io/open-datasets/DEM/GLO-30')
# Load the GLO-30 DEM data from the COPERNICUS collection
srtm = ee.ImageCollection('COPERNICUS/DEM/GLO30') \
          .filterBounds(amazon_basin) \
          .mosaic()

# Calculate slope
slope = ee.Terrain.slope(srtm)

gedi_slope_filtered = gedi_reliable.map(
    lambda feature: feature.updateMask(slope.lte(30))
)

# Step 4: Remove measurements in undesired land cover classes based on WorldCover
worldcover = ee.Image('ESA/WorldCover/v100/2020')
undesired_classes = ee.List([50, 60, 70, 80, 90, 100])


mask_landcover = worldcover.remap(undesired_classes, [0]*6).eq(1)

gedi_landcover_filtered = gedi_slope_filtered.map(
    lambda feature: feature.updateMask(mask_landcover)
)
print("check3")

# Final filtered dataset
gedi_final = gedi_landcover_filtered

print(gedi_final.size().getInfo())

# # Export filtered dataset to Google Cloud Storage
# export_task = ee.batch.Export.table.toCloudStorage(
#     collection=gedi_final,
#     description='Filtered_GEDI_Amazon',
#     bucket='your_gcp_bucket_name',  # Replace with your GCP bucket
#     fileFormat='CSV'
# )
# export_task.start()

# print("Export task started. Check the GCP bucket for results.")
# Out:
# lenght of table id 458
# Check 1
# check2
# check2 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 54
#      51 # Calculate slope
#      52 slope = ee.Terrain.slope(srtm)
# ---> 54 gedi_slope_filtered = gedi_reliable.map(
#      55     lambda feature: feature.updateMask(slope.lte(30))
#      56 )
#      58 # Step 4: Remove measurements in undesired land cover classes based on WorldCover
#      59 worldcover = ee.Image('ESA/WorldCover/v100/2020')
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/collection.py:668, in Collection.map(self, algorithm, dropNulls)
#     665 element_type = self.elementType()
#     666 with_cast = lambda e: algorithm(element_type(e, None))
#     667 return self._cast(
# --> 668     apifunction.ApiFunction.call_(
#     669         'Collection.map', self, with_cast, dropNulls
#     670     )
#     671 )
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/apifunction.py:84, in ApiFunction.call_(cls, name, *args, **kwargs)
#      71 @classmethod
#      72 def call_(cls, name: str, *args: Any, **kwargs: Any) -> Any:
#      73   """Call a named API function with positional and keyword arguments.
#      74
#      75   Args:
#    (...)
#      82     a recognized return type, the returned value will be cast to that type.
#      83   """
# ---> 84   return cls.lookup(name).call(*args, **kwargs)
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/function.py:62, in Function.call(self, *args, **kwargs)
#      50 def call(self, *args, **kwargs):
#      51   """Calls the function with the given positional and keyword arguments.
#      52
#      53   Args:
#    (...)
#      60     to that type.
#      61   """
# ---> 62   return self.apply(self.nameArgs(args, kwargs))
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/function.py:75, in Function.apply(self, named_args)
#      64 def apply(self, named_args):
#      65   """Calls the function with a dictionary of named arguments.
#      66
#      67   Args:
#    (...)
#      73     to that type.
#      74   """
# ---> 75   result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      76   return Function._promoter(result, self.getReturnType())
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/function.py:103, in Function.promoteArgs(self, args)
#     101 name = arg_spec['name']
#     102 if name in args:
# --> 103   promoted_args[name] = Function._promoter(args[name], arg_spec['type'])
#     104 elif not arg_spec.get('optional'):
#     105   raise ee_exception.EEException(
#     106       'Required argument (%s) missing to function: %s'
#     107       % (name, signature.get('name')))
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/__init__.py:336, in _Promote(arg, a_class)
#     333 elif callable(arg):
#     334   # A native function that needs to be wrapped.
#     335   args_count = len(inspect.getfullargspec(arg).args)
# --> 336   return CustomFunction.create(arg, 'Object', ['Object'] * args_count)
#     337 elif isinstance(arg, Encodable):
#     338   # An ee.Function or a computed function like the return value of
#     339   # Image.parseExpression().
#     340   return arg
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/customfunction.py:126, in CustomFunction.create(func, return_type, arg_types)
#     120 args = [{'name': None, 'type': StringifyType(i)} for i in arg_types]
#     121 signature = {
#     122     'name': '',
#     123     'returns': StringifyType(return_type),
#     124     'args': args
#     125 }
# --> 126 return CustomFunction(signature, func)
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/customfunction.py:40, in CustomFunction.__init__(self, signature, body)
#      26 """Creates a function defined by a given expression with unbound variables.
#      27
#      28 The expression is created by evaluating the given function
#    (...)
#      35   body: The Python function to evaluate.
#      36 """
#      37 variables = [CustomFunction.variable(arg['type'], arg['name'])
#      38              for arg in signature['args']]
# ---> 40 if body(*variables) is None:
#      41   raise ee_exception.EEException('User-defined methods must return a value')
#      43 # The signature of the function.
#
# File ~/agb-venv/lib/python3.11/site-packages/ee/collection.py:666, in Collection.map.<locals>.<lambda>(e)
#     648 """Maps an algorithm over a collection.
#     649
#     650 Args:
#    (...)
#     663   ee_exception.EEException: if algorithm is not a function.
#     664 """
#     665 element_type = self.elementType()
# --> 666 with_cast = lambda e: algorithm(element_type(e, None))
#     667 return self._cast(
#     668     apifunction.ApiFunction.call_(
#     669         'Collection.map', self, with_cast, dropNulls
#     670     )
#     671 )
#
# Cell In[26], line 55, in <lambda>(feature)
#      51 # Calculate slope
#      52 slope = ee.Terrain.slope(srtm)
#      54 gedi_slope_filtered = gedi_reliable.map(
# ---> 55     lambda feature: feature.updateMask(slope.lte(30))
#      56 )
#      58 # Step 4: Remove measurements in undesired land cover classes based on WorldCover
#      59 worldcover = ee.Image('ESA/WorldCover/v100/2020')
#
# AttributeError: 'Feature' object has no attribute 'updateMask'
