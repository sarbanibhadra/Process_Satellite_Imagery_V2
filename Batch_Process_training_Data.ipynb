# %%
import ee
import geemap
import folium
import time

ee.Initialize()
Map = geemap.Map(center=[-5.0, -65.0], zoom=5)  # Center near the Amazon region

print("Start")
# Define the region of interest of Amazon basin
# amazon_region_whole = ee.Geometry.Polygon([[[-80.0, 10.0],
#             [-44.0, 10.0],
#             [-44.0, -18.0],                           
#             [-80.0, -18.0],
#             [-80.0, 10.0]]]) 
amazon_region = ee.Geometry.Polygon([[[-78.0, 7.0],
            [-52.0, 7.0],
            [-52.0, -17.0],                           
            [-78.0, -17.0],
            [-78.0, 7.0]]]) 


# Define the bitmasks
cloud_bit_mask = ee.Number(1 << 5)  # Cloud bit is in the 6th bit position
cirrus_bit_mask = ee.Number(1 << 9)  # Cirrus bit is in the 10th bit position

# Define a masking function
def mask_edges(image):
    edge = image.lt(-30.0)  # Define an edge mask where values are less than -30
    masked_image = image.mask().And(edge.Not())  # Mask out edges
    return image.updateMask(masked_image)  # Apply the mask

# Apply the mask using bitwise AND to check that both cloud and cirrus bits are 0
def mask_clouds(image):
    qa = image.select('QA60')  # Select the QA60 band that holds cloud and cirrus bit information
    mask = qa.bitwiseAnd(cloud_bit_mask).eq(0).And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
    return image.updateMask(mask)

# Calculate EVI
def calculate_evi(image):
    return image.expression(
        '2.5 * ((B8 - B4) / (B8 + 6 * B4 - 7.5 * B2 + 1))',
        {
            'B8': image.select('B8'),
            'B4': image.select('B4'),
            'B2': image.select('B2')
        }).rename('EVI')
    
# Function to create a grid of tiles over the region
def create_tile_grid(region, tile_size):
    bounds = region.bounds().coordinates().get(0).getInfo()
    lon_min, lat_min = bounds[0]
    lon_max, lat_max = bounds[2]
    tiles = []
    lon = int(lon_min)
    while int(lon) < int(lon_max):
        lat = int(lat_min)
        while int(lat)+1 < int(lat_max):
            print(lon, lat, lon + tile_size, lat + tile_size)
            tile = ee.Geometry.Rectangle([lon, lat, lon + tile_size, lat + tile_size])
            tiles.append(ee.Feature(tile))
            lat += tile_size
        lon += tile_size
    return ee.FeatureCollection(tiles)



# Tile size in degrees (approx. 300 km × 300 km, depending on latitude)
tile_size_degrees = 2  # Approximate conversion for 300 km
tiles = create_tile_grid(amazon_region, tile_size_degrees)

# Apply batch processing to all tiles
# agb_maps = tiles.map(lambda tile: calculate_agb(tile))

# Process each tile and print the result
tile_list = tiles.toList(tiles.size()).getInfo()  # Convert FeatureCollection to a list
print("Size of tiles", len(tile_list))

print("Generating Map")
# Visualize the tiles on the map
Map.centerObject(amazon_region, 5);
Map.addLayer(amazon_region, {}, 'amazon region');
Map.addLayer(tiles, {'color': 'red'}, 'Tile Grid');
Map
# Out:
# Start
# -78 -17 -76 -15
# -78 -15 -76 -13
# -78 -13 -76 -11
# -78 -11 -76 -9
# -78 -9 -76 -7
# -78 -7 -76 -5
# -78 -5 -76 -3
# -78 -3 -76 -1
# -78 -1 -76 1
# -78 1 -76 3
# -78 3 -76 5
# -78 5 -76 7
# -76 -17 -74 -15
# -76 -15 -74 -13
# -76 -13 -74 -11
# -76 -11 -74 -9
# -76 -9 -74 -7
# -76 -7 -74 -5
# -76 -5 -74 -3
# -76 -3 -74 -1
# -76 -1 -74 1
# -76 1 -74 3
# -76 3 -74 5
# -76 5 -74 7
# -74 -17 -72 -15
# -74 -15 -72 -13
# -74 -13 -72 -11
# -74 -11 -72 -9
# -74 -9 -72 -7
# -74 -7 -72 -5
# -74 -5 -72 -3
# -74 -3 -72 -1
# -74 -1 -72 1
# -74 1 -72 3
# -74 3 -72 5
# -74 5 -72 7
# -72 -17 -70 -15
# -72 -15 -70 -13
# -72 -13 -70 -11
# -72 -11 -70 -9
# -72 -9 -70 -7
# -72 -7 -70 -5
# -72 -5 -70 -3
# -72 -3 -70 -1
# -72 -1 -70 1
# -72 1 -70 3
# -72 3 -70 5
# -72 5 -70 7
# -70 -17 -68 -15
# -70 -15 -68 -13
# -70 -13 -68 -11
# -70 -11 -68 -9
# -70 -9 -68 -7
# -70 -7 -68 -5
# -70 -5 -68 -3
# -70 -3 -68 -1
# -70 -1 -68 1
# -70 1 -68 3
# -70 3 -68 5
# -70 5 -68 7
# -68 -17 -66 -15
# -68 -15 -66 -13
# -68 -13 -66 -11
# -68 -11 -66 -9
# -68 -9 -66 -7
# -68 -7 -66 -5
# -68 -5 -66 -3
# -68 -3 -66 -1
# -68 -1 -66 1
# -68 1 -66 3
# -68 3 -66 5
# -68 5 -66 7
# -66 -17 -64 -15
# -66 -15 -64 -13
# -66 -13 -64 -11
# -66 -11 -64 -9
# -66 -9 -64 -7
# -66 -7 -64 -5
# -66 -5 -64 -3
# -66 -3 -64 -1
# -66 -1 -64 1
# -66 1 -64 3
# -66 3 -64 5
# -66 5 -64 7
# -64 -17 -62 -15
# -64 -15 -62 -13
# -64 -13 -62 -11
# -64 -11 -62 -9
# -64 -9 -62 -7
# -64 -7 -62 -5
# -64 -5 -62 -3
# -64 -3 -62 -1
# -64 -1 -62 1
# -64 1 -62 3
# -64 3 -62 5
# -64 5 -62 7
# -62 -17 -60 -15
# -62 -15 -60 -13
# -62 -13 -60 -11
# -62 -11 -60 -9
# -62 -9 -60 -7
# -62 -7 -60 -5
# -62 -5 -60 -3
# -62 -3 -60 -1
# -62 -1 -60 1
# -62 1 -60 3
# -62 3 -60 5
# -62 5 -60 7
# -60 -17 -58 -15
# -60 -15 -58 -13
# -60 -13 -58 -11
# -60 -11 -58 -9
# -60 -9 -58 -7
# -60 -7 -58 -5
# -60 -5 -58 -3
# -60 -3 -58 -1
# -60 -1 -58 1
# -60 1 -58 3
# -60 3 -58 5
# -60 5 -58 7
# -58 -17 -56 -15
# -58 -15 -56 -13
# -58 -13 -56 -11
# -58 -11 -56 -9
# -58 -9 -56 -7
# -58 -7 -56 -5
# -58 -5 -56 -3
# -58 -3 -56 -1
# -58 -1 -56 1
# -58 1 -56 3
# -58 3 -56 5
# -58 5 -56 7
# -56 -17 -54 -15
# -56 -15 -54 -13
# -56 -13 -54 -11
# -56 -11 -54 -9
# -56 -9 -54 -7
# -56 -7 -54 -5
# -56 -5 -54 -3
# -56 -3 -54 -1
# -56 -1 -54 1
# -56 1 -54 3
# -56 3 -54 5
# -56 5 -54 7
# -54 -17 -52 -15
# -54 -15 -52 -13
# -54 -13 -52 -11
# -54 -11 -52 -9
# -54 -9 -52 -7
# -54 -7 -52 -5
# -54 -5 -52 -3
# -54 -3 -52 -1
# -54 -1 -52 1
# -54 1 -52 3
# -54 3 -52 5
# -54 5 -52 7
# Size of tiles 156
# Generating Map
# Map(center=[-5.044860490756099, -65.00000000000001], controls=(WidgetControl(options=['position', 'transparent…

# %%
###### Function to calculate AGB for each tile
def calculate_agb(tile):
    tile_geometry = ee.Feature(tile).geometry()

    # Load GEDI Level 4A data
    gedi_all = ee.FeatureCollection('LARSE/GEDI/GEDI04_A_002_INDEX')\
            .filter('time_start > "2022-01-01" && time_end < "2022-03-31"')\
            .filterBounds(tile_geometry);

    # Get the list of table_id values
    table_ids = gedi_all.aggregate_array('table_id').getInfo()
    print("Lenght of table id", len(table_ids))
    
    # Initialize an empty FeatureCollection
    gedi = ee.FeatureCollection([])

    # Loop through each table ID and merge them
    for table_id in table_ids:
        # Load each table and merge
        table = ee.FeatureCollection(table_id).filterBounds(tile_geometry)
        # image = image.reproject('EPSG:4326', None, 100)
        gedi = gedi.merge(table)
        # print("Size of Gedi", gedi.size().getInfo())
    print('Number of GEDI points:', gedi.size().getInfo())

    # Filter invalid AGBD measurements based on 'l4_quality_flag'
    gedi = gedi.filter(ee.Filter.eq('l4_quality_flag', 1))
    print('Number of first filtered GEDI points:', gedi.size().getInfo())
    
    # Filter to keep only points with non-null 'agbd' values
    gedi = gedi.filter(ee.Filter.notNull(['agbd']))
    gedi_size = gedi.size().getInfo()
    print('Number of 2nd filtered GEDI points:', gedi_size)
    if gedi_size != 0:
        # Map.setCenter(-60, 5, 5);
        # Map.addLayer(merged_granules);
        # print(gedi.first().getInfo())
        # load sentinel-1 data 
        spring = ee.Filter.date('2022-01-01', '2022-03-31');
        lateSpring = ee.Filter.date('2022-01-21', '2022-03-31');
        summer = ee.Filter.date('2022-01-11', '2022-03-31');
    
        sentinel1 = ee.ImageCollection('COPERNICUS/S1_GRD')\
                    .filterBounds(tile_geometry)\
                    .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV'))\
                    .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH'))\
                    .filter(ee.Filter.eq('instrumentMode', 'IW'))\
                    .filter(ee.Filter.inList('orbitProperties_pass', ['ASCENDING', 'DESCENDING']))
        # Select the VV and VH bands
        sentinel1_vv = sentinel1.select('VV')
        sentinel1_vh = sentinel1.select('VH')
        # Apply the masking function to each image in the collection
        sentinel1_vv_masked = sentinel1_vv.map(mask_edges)
        sentinel1_vv_final = ee.Image.cat(
                sentinel1_vv_masked.filter(spring).mean(),
                sentinel1_vv_masked.filter(lateSpring).mean(),
                sentinel1_vv_masked.filter(summer).mean());
        # Apply the masking function to each image in the collection
        sentinel1_vh_masked = sentinel1_vh.map(mask_edges)
        sentinel1_vh_final = ee.Image.cat(
                sentinel1_vh_masked.filter(spring).mean(),
                sentinel1_vh_masked.filter(lateSpring).mean(),
                sentinel1_vh_masked.filter(summer).mean());
        # print('Number of sentinel1 points:', sentinel1_vh_masked.size().getInfo(), sentinel1_vv_masked.size().getInfo()) 
        
        
        # Load Sentinel-2 surface reflectance data
        # Sentinel-2 Level 2A multispectral imagery, ref:  https://www.sciencedirect.com/science/article/pii/S1569843222002965#s0010
        sentinel2 = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
                        .filterBounds(tile_geometry) \
                        .filterDate('2022-01-01', '2022-03-31') \
                        .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 40))
        # Define the bitmasks
        cloud_bit_mask = ee.Number(1 << 5)  # Cloud bit is in the 6th bit position
        cirrus_bit_mask = ee.Number(1 << 9)  # Cirrus bit is in the 10th bit position
    
        sentinel2 = sentinel2.map(mask_clouds)
        # Calculate NDVI
        ndvi = sentinel2.map(lambda image: image.normalizedDifference(['B8', 'B4']).rename('NDVI')).median()
        # print('Number of sentinel2 points:', sentinel2.size().getInfo()) 
       
        evi = sentinel2.map(calculate_evi).median()
        # print('Number of evi points:', evi.getInfo())
        
        
        # Load Landsat 8 Surface Reflectance data
        landsat8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2') \
                      .filterBounds(tile_geometry) \
                      .filterDate('2022-01-01', '2022-03-31') \
                      .filter(ee.Filter.lt('CLOUD_COVER', 35))

        # Calculate NDVI for Landsat 8
        landsat_ndvi = landsat8.map(lambda image: image.normalizedDifference(['SR_B5', 'SR_B4']).rename('NDVI')).median()

        
        
        # Load the GLO-30 DEM data from the COPERNICUS collection
        dem = ee.ImageCollection('COPERNICUS/DEM/GLO30') \
                  .filterBounds(tile_geometry) \
                  .mosaic()
        
        # Calculate slope in degrees
        slope = ee.Terrain.slope(dem)
        # Calculate aspect in degrees
        aspect = ee.Terrain.aspect(dem)
        # print('Number of dem points:')

        # print('Number of ndvi points:', ndvi.getInfo())
        # print('Number of evi points:', evi.getInfo())
        # print('Number of landsat_ndvi points:', landsat_ndvi.getInfo())
        # print('Number of dem points:', dem.getInfo())
        # print('Number of slope points:', slope.getInfo())
        # print('Number of aspect points:', aspect.getInfo())
        # Stack all the features (Sentinel-1, Sentinel-2, Landsat, DEM)
        feature_stack = sentinel1_vh_final.addBands(sentinel1_vv_final) \
                                    .addBands(ndvi) \
                                    .addBands(evi) \
                                    .addBands(landsat_ndvi) \
                                    .addBands(dem) \
                                    .addBands(slope) \
                                    .addBands(aspect)
        
        # print('Size of feature stack :', feature_stack.getInfo())
        
        # Sample the remote sensing data at GEDI footprint locations
        training_data = feature_stack.sampleRegions(
            collection=gedi,
            properties=['agbd'],
            scale=100,
            tileScale=16,
            geometries=True
        )

        # # from sklearn.impute import KNNImputer

        # # Select numeric columns for imputation
        # features = training_data[['sentinel1_vh_final', 'sentinel1_vh_final', 'ndvi']]  # Add relevant predictors
        # imputer = KNNImputer(n_neighbors=5)
        # training_data['agbd'] = imputer.fit_transform(features)[:, -1]
                
        # print('Number of training_data points:', training_data.size().getInfo())
        # if training_data.size().getInfo() == 0:
        #     return None
        
        # # Train a Random Forest model
        # classifier = ee.Classifier.smileRandomForest(50).setOutputMode('REGRESSION')
        
        # # print('Before trained_model points')
        # # Train the model
        # trained_model = classifier.train(
        #     features=training_data,
        #     classProperty='agbd',
        #     inputProperties=feature_stack.bandNames()
        # )
        
        # # Apply the trained model to predict AGB
        # agb_prediction = feature_stack.classify(trained_model).reproject(crs='EPSG:3857', scale=100) 
        return training_data
        

# Function to check task status periodically
def check_task_status(task):
    while True:
        status = task.status()
        state = status['state']
        print('Current task state:', state)
        
        if state == 'COMPLETED':
            print("Export task completed successfully.")
            break
        elif state == 'FAILED':
            print("Export task failed:", status)
            break
        
        # Wait before checking the status again
        time.sleep(30)


agb_list = []
c=0
for tile in tile_list:
    training_data = calculate_agb(tile)
    # # Reduce the ImageCollection to a single image (e.g., median)
    # agb_prediction_image = agb_prediction.median()

    # Assuming `agb_prediction` is an ee.Image and `region` is an ee.Geometry
    # Export the FeatureCollection to Google Drive
    task = ee.batch.Export.table.toCloudStorage(
        collection=training_data,
        description='Export_training_data_to_CloudStorage',
        bucket='test-agb-bucket',  # Replace with your GCS bucket name
        fileNamePrefix=f'agb_training_data_{c}',  # Replace with desired file path and prefix
        fileFormat='CSV'  # Format can be 'CSV', 'GeoJSON', etc.
    )

    if agb_prediction != None:
        # agb_list.append(agb)
        # Start the task
        task.start()
        status = task.status()
        print(status)
        print("Export started")
        # Start monitoring the task
        check_task_status(task)
    c=c+1
    # if c == 12:
    #     break

# agb_map = ee.ImageCollection(agb_list)
    
# print("Size of agbs", agb_map.size().getInfo())
# Map.addLayer(agb_map, {'min': 0, 'max': 300, 'palette': ['5F9EA0', 'grey', 'yellow', '7CFC00','5F8575', '228B22','008000', 
#         '355E3B', '4F7942']}, 'Predicted AGB')

# Map.centerObject(amazon_region, 5);
# Map
# Out:
# Lenght of table id 26
# Number of GEDI points: 534756
# Number of first filtered GEDI points: 0
# Number of 2nd filtered GEDI points: 0
# Lenght of table id 21
# Number of GEDI points: 418548
# Number of first filtered GEDI points: 2056
# Number of 2nd filtered GEDI points: 2056
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733515415813, 'update_timestamp_ms': 1733515415813, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'BPJK2CDCZJSLSIALADAUB3PI', 'name': 'projects/test-project-agb/operations/BPJK2CDCZJSLSIALADAUB3PI'}
# Export started
# Current task state: READY
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 28
# Number of GEDI points: 606463
# Number of first filtered GEDI points: 3712
# Number of 2nd filtered GEDI points: 3712
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733515484341, 'update_timestamp_ms': 1733515484341, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'UGPUT5MQTFMHR7IFZKZ6CHS4', 'name': 'projects/test-project-agb/operations/UGPUT5MQTFMHR7IFZKZ6CHS4'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 29
# Number of GEDI points: 684675
# Number of first filtered GEDI points: 14560
# Number of 2nd filtered GEDI points: 14560
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733515589389, 'update_timestamp_ms': 1733515589389, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'RBXQS3ZMEHB2YC3EZ2DPOWUR', 'name': 'projects/test-project-agb/operations/RBXQS3ZMEHB2YC3EZ2DPOWUR'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 20
# Number of GEDI points: 388037
# Number of first filtered GEDI points: 34226
# Number of 2nd filtered GEDI points: 34226
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733515712631, 'update_timestamp_ms': 1733515712631, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '73APWSOWSY5VENSESLF5IYKS', 'name': 'projects/test-project-agb/operations/73APWSOWSY5VENSESLF5IYKS'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 17
# Number of GEDI points: 317480
# Number of first filtered GEDI points: 68003
# Number of 2nd filtered GEDI points: 68003
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733515896856, 'update_timestamp_ms': 1733515896856, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'QJ3WRSU6TRD36FBYTVNKWYMD', 'name': 'projects/test-project-agb/operations/QJ3WRSU6TRD36FBYTVNKWYMD'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 509170
# Number of first filtered GEDI points: 48558
# Number of 2nd filtered GEDI points: 48558
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733516088622, 'update_timestamp_ms': 1733516088622, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'VAHEYVUNVDSHV2CYHBLJCDBO', 'name': 'projects/test-project-agb/operations/VAHEYVUNVDSHV2CYHBLJCDBO'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 26
# Number of GEDI points: 627718
# Number of first filtered GEDI points: 124622
# Number of 2nd filtered GEDI points: 124622
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733516321190, 'update_timestamp_ms': 1733516321190, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'BVBV54SN6Y3S4Z6I3EF6HV23', 'name': 'projects/test-project-agb/operations/BVBV54SN6Y3S4Z6I3EF6HV23'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733516321190, 'update_timestamp_ms': 1733516374988, 'start_timestamp_ms': 1733516328712, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1698.799682617, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'BVBV54SN6Y3S4Z6I3EF6HV23', 'name': 'projects/test-project-agb/operations/BVBV54SN6Y3S4Z6I3EF6HV23'}
# Lenght of table id 36
# Number of GEDI points: 464688
# Number of first filtered GEDI points: 99903
# Number of 2nd filtered GEDI points: 99903
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733516432199, 'update_timestamp_ms': 1733516432199, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '3AUDES7A7VYHZGS77R5AW4XV', 'name': 'projects/test-project-agb/operations/3AUDES7A7VYHZGS77R5AW4XV'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 19
# Number of GEDI points: 369595
# Number of first filtered GEDI points: 30902
# Number of 2nd filtered GEDI points: 30902
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733516834302, 'update_timestamp_ms': 1733516834302, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'SHOIWJDBV64ZTZN2NCTM5UT2', 'name': 'projects/test-project-agb/operations/SHOIWJDBV64ZTZN2NCTM5UT2'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 20
# Number of GEDI points: 456216
# Number of first filtered GEDI points: 22976
# Number of 2nd filtered GEDI points: 22976
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733517022926, 'update_timestamp_ms': 1733517022926, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'WW6VQULV3FOWE367CCSHEFVI', 'name': 'projects/test-project-agb/operations/WW6VQULV3FOWE367CCSHEFVI'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 26
# Number of GEDI points: 546391
# Number of first filtered GEDI points: 43742
# Number of 2nd filtered GEDI points: 43742
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733517166463, 'update_timestamp_ms': 1733517166463, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'VDITPRYLHHHV4HSSR6XTCRS6', 'name': 'projects/test-project-agb/operations/VDITPRYLHHHV4HSSR6XTCRS6'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 26
# Number of GEDI points: 589555
# Number of first filtered GEDI points: 5524
# Number of 2nd filtered GEDI points: 5524
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733517423005, 'update_timestamp_ms': 1733517423005, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'NS5AXMOKNKPSETWFDRSCT4HC', 'name': 'projects/test-project-agb/operations/NS5AXMOKNKPSETWFDRSCT4HC'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 29
# Number of GEDI points: 563858
# Number of first filtered GEDI points: 16257
# Number of 2nd filtered GEDI points: 16257
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733517525213, 'update_timestamp_ms': 1733517525213, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '7BMMQE47BNTDSB22C33WBJWD', 'name': 'projects/test-project-agb/operations/7BMMQE47BNTDSB22C33WBJWD'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 532715
# Number of first filtered GEDI points: 24289
# Number of 2nd filtered GEDI points: 24289
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733517763420, 'update_timestamp_ms': 1733517763420, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'IH74LY7MM5PXZ2CRGDTZJLQB', 'name': 'projects/test-project-agb/operations/IH74LY7MM5PXZ2CRGDTZJLQB'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 23
# Number of GEDI points: 463236
# Number of first filtered GEDI points: 41353
# Number of 2nd filtered GEDI points: 41353
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733518049444, 'update_timestamp_ms': 1733518049444, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'LGITTVVE7DVX7NKB6FIPOB5J', 'name': 'projects/test-project-agb/operations/LGITTVVE7DVX7NKB6FIPOB5J'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 521002
# Number of first filtered GEDI points: 140810
# Number of 2nd filtered GEDI points: 140810
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733518214545, 'update_timestamp_ms': 1733518214545, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'FUCKLJI6DJ4JE7C4O4WAXCRR', 'name': 'projects/test-project-agb/operations/FUCKLJI6DJ4JE7C4O4WAXCRR'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733518214545, 'update_timestamp_ms': 1733518279896, 'start_timestamp_ms': 1733518231524, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1638.659667968, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'FUCKLJI6DJ4JE7C4O4WAXCRR', 'name': 'projects/test-project-agb/operations/FUCKLJI6DJ4JE7C4O4WAXCRR'}
# Lenght of table id 23
# Number of GEDI points: 479810
# Number of first filtered GEDI points: 111046
# Number of 2nd filtered GEDI points: 111046
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733518349632, 'update_timestamp_ms': 1733518349632, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '6K4OGZJMRYAS2WU6DOV7GPWL', 'name': 'projects/test-project-agb/operations/6K4OGZJMRYAS2WU6DOV7GPWL'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 21
# Number of GEDI points: 450477
# Number of first filtered GEDI points: 48405
# Number of 2nd filtered GEDI points: 48405
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733518662768, 'update_timestamp_ms': 1733518662768, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'GURJT3C2DULEOLQNWBFPPNTC', 'name': 'projects/test-project-agb/operations/GURJT3C2DULEOLQNWBFPPNTC'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 21
# Number of GEDI points: 475114
# Number of first filtered GEDI points: 90096
# Number of 2nd filtered GEDI points: 90096
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733519041067, 'update_timestamp_ms': 1733519041067, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'DNNAPTWAQMR4BONXBI5TMDAN', 'name': 'projects/test-project-agb/operations/DNNAPTWAQMR4BONXBI5TMDAN'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 35
# Number of GEDI points: 499561
# Number of first filtered GEDI points: 161792
# Number of 2nd filtered GEDI points: 161792
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733519258645, 'update_timestamp_ms': 1733519258645, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'MHEUVQRR5BSIMURFVGMN4T7I', 'name': 'projects/test-project-agb/operations/MHEUVQRR5BSIMURFVGMN4T7I'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733519258645, 'update_timestamp_ms': 1733519308955, 'start_timestamp_ms': 1733519269283, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1559.783203125, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'MHEUVQRR5BSIMURFVGMN4T7I', 'name': 'projects/test-project-agb/operations/MHEUVQRR5BSIMURFVGMN4T7I'}
# Lenght of table id 22
# Number of GEDI points: 502711
# Number of first filtered GEDI points: 57064
# Number of 2nd filtered GEDI points: 57064
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733519357352, 'update_timestamp_ms': 1733519357352, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'LKCG4WNJF2G57DSGIB6T4YPW', 'name': 'projects/test-project-agb/operations/LKCG4WNJF2G57DSGIB6T4YPW'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 511921
# Number of first filtered GEDI points: 121655
# Number of 2nd filtered GEDI points: 121655
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733519556733, 'update_timestamp_ms': 1733519556733, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '3PGIYVF5ARHKQ3VC2AZ337X4', 'name': 'projects/test-project-agb/operations/3PGIYVF5ARHKQ3VC2AZ337X4'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 523677
# Number of first filtered GEDI points: 108503
# Number of 2nd filtered GEDI points: 108503
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733519879834, 'update_timestamp_ms': 1733519879834, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'DMIOPKSORFYFPV4VFDMWVOEL', 'name': 'projects/test-project-agb/operations/DMIOPKSORFYFPV4VFDMWVOEL'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 27
# Number of GEDI points: 547131
# Number of first filtered GEDI points: 45152
# Number of 2nd filtered GEDI points: 45152
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733520070354, 'update_timestamp_ms': 1733520070354, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'BYC6KCRO7G5Z2S3OSNQWAJMG', 'name': 'projects/test-project-agb/operations/BYC6KCRO7G5Z2S3OSNQWAJMG'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 30
# Number of GEDI points: 655764
# Number of first filtered GEDI points: 29026
# Number of 2nd filtered GEDI points: 29026
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733520295304, 'update_timestamp_ms': 1733520295304, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'AR7H5L3HRVCC6TQ6ARF5AUJN', 'name': 'projects/test-project-agb/operations/AR7H5L3HRVCC6TQ6ARF5AUJN'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 443866
# Number of first filtered GEDI points: 72172
# Number of 2nd filtered GEDI points: 72172
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733520488134, 'update_timestamp_ms': 1733520488134, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'AIKFSEFYRS2HNRXA23GZJVPW', 'name': 'projects/test-project-agb/operations/AIKFSEFYRS2HNRXA23GZJVPW'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 19
# Number of GEDI points: 390595
# Number of first filtered GEDI points: 72530
# Number of 2nd filtered GEDI points: 72530
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733520828416, 'update_timestamp_ms': 1733520828416, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'ADS2HFFG6R2OSMQBYVF2OPKN', 'name': 'projects/test-project-agb/operations/ADS2HFFG6R2OSMQBYVF2OPKN'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 544676
# Number of first filtered GEDI points: 65990
# Number of 2nd filtered GEDI points: 65990
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733521062844, 'update_timestamp_ms': 1733521062844, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'AII2E3OPDGZKGKIJLDLV76UK', 'name': 'projects/test-project-agb/operations/AII2E3OPDGZKGKIJLDLV76UK'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 28
# Number of GEDI points: 631051
# Number of first filtered GEDI points: 124443
# Number of 2nd filtered GEDI points: 124443
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733521337602, 'update_timestamp_ms': 1733521337602, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'Z6PJE7ANFRGER7QEOSDUFYB5', 'name': 'projects/test-project-agb/operations/Z6PJE7ANFRGER7QEOSDUFYB5'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733521337602, 'update_timestamp_ms': 1733521378640, 'start_timestamp_ms': 1733521350744, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1462.23461914, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'Z6PJE7ANFRGER7QEOSDUFYB5', 'name': 'projects/test-project-agb/operations/Z6PJE7ANFRGER7QEOSDUFYB5'}
# Lenght of table id 21
# Number of GEDI points: 495116
# Number of first filtered GEDI points: 102875
# Number of 2nd filtered GEDI points: 102875
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733521445435, 'update_timestamp_ms': 1733521445435, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'HN4JCVZE5ZF7SSY76SGZCKBV', 'name': 'projects/test-project-agb/operations/HN4JCVZE5ZF7SSY76SGZCKBV'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 19
# Number of GEDI points: 316369
# Number of first filtered GEDI points: 135973
# Number of 2nd filtered GEDI points: 135973
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733521910015, 'update_timestamp_ms': 1733521910015, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'YPA6PZQNXN2DWVIUFHETBUO4', 'name': 'projects/test-project-agb/operations/YPA6PZQNXN2DWVIUFHETBUO4'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733521910015, 'update_timestamp_ms': 1733521944639, 'start_timestamp_ms': 1733521916853, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1083.077148437, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'YPA6PZQNXN2DWVIUFHETBUO4', 'name': 'projects/test-project-agb/operations/YPA6PZQNXN2DWVIUFHETBUO4'}
# Lenght of table id 39
# Number of GEDI points: 493512
# Number of first filtered GEDI points: 135413
# Number of 2nd filtered GEDI points: 135413
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733522030705, 'update_timestamp_ms': 1733522030705, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'HBV6EPG433NOAVM7VWFP6EXH', 'name': 'projects/test-project-agb/operations/HBV6EPG433NOAVM7VWFP6EXH'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 28
# Number of GEDI points: 650233
# Number of first filtered GEDI points: 167528
# Number of 2nd filtered GEDI points: 167528
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733522328130, 'update_timestamp_ms': 1733522328130, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '6HPPNEEWDLWV4SG5GOYCFXUH', 'name': 'projects/test-project-agb/operations/6HPPNEEWDLWV4SG5GOYCFXUH'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733522328130, 'update_timestamp_ms': 1733522436548, 'start_timestamp_ms': 1733522335757, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1623.719482421, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': '6HPPNEEWDLWV4SG5GOYCFXUH', 'name': 'projects/test-project-agb/operations/6HPPNEEWDLWV4SG5GOYCFXUH'}
# Lenght of table id 26
# Number of GEDI points: 547487
# Number of first filtered GEDI points: 75770
# Number of 2nd filtered GEDI points: 75770
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733522504817, 'update_timestamp_ms': 1733522504817, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'WQ24HUP5FTDU2BOFKLXI6A6B', 'name': 'projects/test-project-agb/operations/WQ24HUP5FTDU2BOFKLXI6A6B'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 19
# Number of GEDI points: 393184
# Number of first filtered GEDI points: 93689
# Number of 2nd filtered GEDI points: 93689
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733522937075, 'update_timestamp_ms': 1733522937075, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'XDYCVHTWUH3LOQ66GAU6JXVQ', 'name': 'projects/test-project-agb/operations/XDYCVHTWUH3LOQ66GAU6JXVQ'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 455348
# Number of first filtered GEDI points: 18033
# Number of 2nd filtered GEDI points: 18033
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733523744126, 'update_timestamp_ms': 1733523744126, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '4GTMK4X2FJRK6EZ4D3QJJ2LY', 'name': 'projects/test-project-agb/operations/4GTMK4X2FJRK6EZ4D3QJJ2LY'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 17
# Number of GEDI points: 307376
# Number of first filtered GEDI points: 15622
# Number of 2nd filtered GEDI points: 15622
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733523837126, 'update_timestamp_ms': 1733523837126, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'SAKS3IEG7A6WFGUKYTSNUYPQ', 'name': 'projects/test-project-agb/operations/SAKS3IEG7A6WFGUKYTSNUYPQ'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 564844
# Number of first filtered GEDI points: 129060
# Number of 2nd filtered GEDI points: 129060
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733523983370, 'update_timestamp_ms': 1733523983370, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'ROV6LBRWPFCSSVIXTS76S2LS', 'name': 'projects/test-project-agb/operations/ROV6LBRWPFCSSVIXTS76S2LS'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733523983370, 'update_timestamp_ms': 1733524042794, 'start_timestamp_ms': 1733523996544, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1912.681274414, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'ROV6LBRWPFCSSVIXTS76S2LS', 'name': 'projects/test-project-agb/operations/ROV6LBRWPFCSSVIXTS76S2LS'}
# Lenght of table id 29
# Number of GEDI points: 664012
# Number of first filtered GEDI points: 106930
# Number of 2nd filtered GEDI points: 106930
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733524103792, 'update_timestamp_ms': 1733524103792, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'CRCFV6GCHUIECKGG6T3AMP4I', 'name': 'projects/test-project-agb/operations/CRCFV6GCHUIECKGG6T3AMP4I'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 454854
# Number of first filtered GEDI points: 137969
# Number of 2nd filtered GEDI points: 137969
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733524498418, 'update_timestamp_ms': 1733524498418, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'OEYM32UHQSHOTQDBNUOO7Z7Y', 'name': 'projects/test-project-agb/operations/OEYM32UHQSHOTQDBNUOO7Z7Y'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733524498418, 'update_timestamp_ms': 1733524545647, 'start_timestamp_ms': 1733524508983, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 2082.418701171, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'OEYM32UHQSHOTQDBNUOO7Z7Y', 'name': 'projects/test-project-agb/operations/OEYM32UHQSHOTQDBNUOO7Z7Y'}
# Lenght of table id 19
# Number of GEDI points: 388742
# Number of first filtered GEDI points: 100729
# Number of 2nd filtered GEDI points: 100729
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733524590364, 'update_timestamp_ms': 1733524590364, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'HB5UBCBFGQXVHRDZMG7DAH5U', 'name': 'projects/test-project-agb/operations/HB5UBCBFGQXVHRDZMG7DAH5U'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 27
# Number of GEDI points: 525178
# Number of first filtered GEDI points: 91423
# Number of 2nd filtered GEDI points: 91423
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733524830564, 'update_timestamp_ms': 1733524830564, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'F56CRKHCLYAEQUGM7MMHSGZ6', 'name': 'projects/test-project-agb/operations/F56CRKHCLYAEQUGM7MMHSGZ6'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 28
# Number of GEDI points: 696572
# Number of first filtered GEDI points: 118570
# Number of 2nd filtered GEDI points: 118570
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733525184620, 'update_timestamp_ms': 1733525184620, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'HRQF2G7PWLCPWHYLACCVMQDP', 'name': 'projects/test-project-agb/operations/HRQF2G7PWLCPWHYLACCVMQDP'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 38
# Number of GEDI points: 480510
# Number of first filtered GEDI points: 141999
# Number of 2nd filtered GEDI points: 141999
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733525724157, 'update_timestamp_ms': 1733525724157, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '7MQMMOM3TYZCIGEYPVAXHWD6', 'name': 'projects/test-project-agb/operations/7MQMMOM3TYZCIGEYPVAXHWD6'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733525724157, 'update_timestamp_ms': 1733525791219, 'start_timestamp_ms': 1733525731366, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1258.243774414, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': '7MQMMOM3TYZCIGEYPVAXHWD6', 'name': 'projects/test-project-agb/operations/7MQMMOM3TYZCIGEYPVAXHWD6'}
# Lenght of table id 18
# Number of GEDI points: 363367
# Number of first filtered GEDI points: 119005
# Number of 2nd filtered GEDI points: 119005
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733525854046, 'update_timestamp_ms': 1733525854046, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '3BVRFTQ54UWJPGWCI75ISRKK', 'name': 'projects/test-project-agb/operations/3BVRFTQ54UWJPGWCI75ISRKK'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 497923
# Number of first filtered GEDI points: 96690
# Number of 2nd filtered GEDI points: 96690
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733526127049, 'update_timestamp_ms': 1733526127049, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '27DAR22FMCWLRYTWTI4MDEVK', 'name': 'projects/test-project-agb/operations/27DAR22FMCWLRYTWTI4MDEVK'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 30
# Number of GEDI points: 676800
# Number of first filtered GEDI points: 125467
# Number of 2nd filtered GEDI points: 125467
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733526500567, 'update_timestamp_ms': 1733526500567, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'E6COFYN4WKPQJWA4DGPKYVWB', 'name': 'projects/test-project-agb/operations/E6COFYN4WKPQJWA4DGPKYVWB'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 21
# Number of GEDI points: 424060
# Number of first filtered GEDI points: 24940
# Number of 2nd filtered GEDI points: 24940
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733526965869, 'update_timestamp_ms': 1733526965869, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'MRLVRFZHCBLMKU3IQ74QTQYT', 'name': 'projects/test-project-agb/operations/MRLVRFZHCBLMKU3IQ74QTQYT'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 524561
# Number of first filtered GEDI points: 160049
# Number of 2nd filtered GEDI points: 160049
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733527134266, 'update_timestamp_ms': 1733527134266, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'CPKNF6TFFXAXPL3U2J3LCPQV', 'name': 'projects/test-project-agb/operations/CPKNF6TFFXAXPL3U2J3LCPQV'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733527134266, 'update_timestamp_ms': 1733527220681, 'start_timestamp_ms': 1733527138970, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1903.970092773, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'CPKNF6TFFXAXPL3U2J3LCPQV', 'name': 'projects/test-project-agb/operations/CPKNF6TFFXAXPL3U2J3LCPQV'}
# Lenght of table id 22
# Number of GEDI points: 459918
# Number of first filtered GEDI points: 115165
# Number of 2nd filtered GEDI points: 115165
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733527270123, 'update_timestamp_ms': 1733527270123, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'R5V6WLF4N5L4PMNAX4LSJ6XF', 'name': 'projects/test-project-agb/operations/R5V6WLF4N5L4PMNAX4LSJ6XF'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 469904
# Number of first filtered GEDI points: 80790
# Number of 2nd filtered GEDI points: 80790
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733527673926, 'update_timestamp_ms': 1733527673926, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'SOI2AUXBVVJYCTDTSKNG3F4K', 'name': 'projects/test-project-agb/operations/SOI2AUXBVVJYCTDTSKNG3F4K'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 550923
# Number of first filtered GEDI points: 116808
# Number of 2nd filtered GEDI points: 116808
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733527875657, 'update_timestamp_ms': 1733527875657, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'WNCDBJZW2BWGBUAV2FEISEX3', 'name': 'projects/test-project-agb/operations/WNCDBJZW2BWGBUAV2FEISEX3'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 533075
# Number of first filtered GEDI points: 52517
# Number of 2nd filtered GEDI points: 52517
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733528497508, 'update_timestamp_ms': 1733528497508, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'RGFJDT4BYBJVQJ2BWXXGD657', 'name': 'projects/test-project-agb/operations/RGFJDT4BYBJVQJ2BWXXGD657'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 537060
# Number of first filtered GEDI points: 54827
# Number of 2nd filtered GEDI points: 54827
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733528756377, 'update_timestamp_ms': 1733528756377, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'KMVKBBFIIDRFPPMLV2DEES5Y', 'name': 'projects/test-project-agb/operations/KMVKBBFIIDRFPPMLV2DEES5Y'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 512219
# Number of first filtered GEDI points: 122900
# Number of 2nd filtered GEDI points: 122900
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733529079829, 'update_timestamp_ms': 1733529079829, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '6UG7HL43IXIRI4XOX5JM7BSH', 'name': 'projects/test-project-agb/operations/6UG7HL43IXIRI4XOX5JM7BSH'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 40
# Number of GEDI points: 574420
# Number of first filtered GEDI points: 119650
# Number of 2nd filtered GEDI points: 119650
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733529718218, 'update_timestamp_ms': 1733529718218, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'HAB6I5UIXQI6W3LOWS2AU4ST', 'name': 'projects/test-project-agb/operations/HAB6I5UIXQI6W3LOWS2AU4ST'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 24
# Number of GEDI points: 525695
# Number of first filtered GEDI points: 126156
# Number of 2nd filtered GEDI points: 126156
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733530255278, 'update_timestamp_ms': 1733530255278, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'IHSLW2NSEN7QFQU56RNIYDHP', 'name': 'projects/test-project-agb/operations/IHSLW2NSEN7QFQU56RNIYDHP'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 23
# Number of GEDI points: 499049
# Number of first filtered GEDI points: 138610
# Number of 2nd filtered GEDI points: 138610
# ...
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 540595
# Number of first filtered GEDI points: 126384
# Number of 2nd filtered GEDI points: 126384
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559084134, 'update_timestamp_ms': 1733559084134, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'VHQKSZV5IYKPBHSISHSDBAUY', 'name': 'projects/test-project-agb/operations/VHQKSZV5IYKPBHSISHSDBAUY'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559084134, 'update_timestamp_ms': 1733559221483, 'start_timestamp_ms': 1733559090933, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1776.982421875, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'VHQKSZV5IYKPBHSISHSDBAUY', 'name': 'projects/test-project-agb/operations/VHQKSZV5IYKPBHSISHSDBAUY'}
# Lenght of table id 21
# Number of GEDI points: 426553
# Number of first filtered GEDI points: 145486
# Number of 2nd filtered GEDI points: 145486
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559282116, 'update_timestamp_ms': 1733559282116, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'HBY2ONF4E7W5SXNB37UE6M3X', 'name': 'projects/test-project-agb/operations/HBY2ONF4E7W5SXNB37UE6M3X'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559282116, 'update_timestamp_ms': 1733559334043, 'start_timestamp_ms': 1733559292764, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 1546.321411132, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'HBY2ONF4E7W5SXNB37UE6M3X', 'name': 'projects/test-project-agb/operations/HBY2ONF4E7W5SXNB37UE6M3X'}
# Lenght of table id 22
# Number of GEDI points: 388659
# Number of first filtered GEDI points: 74309
# Number of 2nd filtered GEDI points: 74309
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559377893, 'update_timestamp_ms': 1733559377893, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'DPXDCZJTPMF2A2MG2SZK7DND', 'name': 'projects/test-project-agb/operations/DPXDCZJTPMF2A2MG2SZK7DND'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 34
# Number of GEDI points: 515010
# Number of first filtered GEDI points: 97508
# Number of 2nd filtered GEDI points: 97508
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559707661, 'update_timestamp_ms': 1733559707661, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'ZUU4TB36L77XPM4NKAV6NUTB', 'name': 'projects/test-project-agb/operations/ZUU4TB36L77XPM4NKAV6NUTB'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 21
# Number of GEDI points: 478151
# Number of first filtered GEDI points: 52833
# Number of 2nd filtered GEDI points: 52833
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559805757, 'update_timestamp_ms': 1733559805757, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'GR5YS5ET3RG7GLLUCVQK7N7W', 'name': 'projects/test-project-agb/operations/GR5YS5ET3RG7GLLUCVQK7N7W'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 20
# Number of GEDI points: 429853
# Number of first filtered GEDI points: 67249
# Number of 2nd filtered GEDI points: 67249
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733559944643, 'update_timestamp_ms': 1733559944643, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'E47ROLTV3M2ZDV3YHZ3GYR54', 'name': 'projects/test-project-agb/operations/E47ROLTV3M2ZDV3YHZ3GYR54'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 20
# Number of GEDI points: 429691
# Number of first filtered GEDI points: 29643
# Number of 2nd filtered GEDI points: 29643
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733560188268, 'update_timestamp_ms': 1733560188268, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': '52FSDWCC5JKDNSRWCFBLYAGY', 'name': 'projects/test-project-agb/operations/52FSDWCC5JKDNSRWCFBLYAGY'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 25
# Number of GEDI points: 497990
# Number of first filtered GEDI points: 91261
# Number of 2nd filtered GEDI points: 91261
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733560363812, 'update_timestamp_ms': 1733560363812, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'RWT5GP6BERMXYZ2GMWBWDFWC', 'name': 'projects/test-project-agb/operations/RWT5GP6BERMXYZ2GMWBWDFWC'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 19
# Number of GEDI points: 379210
# Number of first filtered GEDI points: 34661
# Number of 2nd filtered GEDI points: 34661
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733560739738, 'update_timestamp_ms': 1733560739738, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'IJNDLIXAA2T6NREBQN3SIIVE', 'name': 'projects/test-project-agb/operations/IJNDLIXAA2T6NREBQN3SIIVE'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 26
# Number of GEDI points: 574319
# Number of first filtered GEDI points: 153455
# Number of 2nd filtered GEDI points: 153455
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561127117, 'update_timestamp_ms': 1733561127117, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'CNNGXIWIRI6J2XL4LQEWL4QG', 'name': 'projects/test-project-agb/operations/CNNGXIWIRI6J2XL4LQEWL4QG'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561127117, 'update_timestamp_ms': 1733561185793, 'start_timestamp_ms': 1733561131994, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 3415.906005859, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'CNNGXIWIRI6J2XL4LQEWL4QG', 'name': 'projects/test-project-agb/operations/CNNGXIWIRI6J2XL4LQEWL4QG'}
# Lenght of table id 29
# Number of GEDI points: 713893
# Number of first filtered GEDI points: 201626
# Number of 2nd filtered GEDI points: 201626
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561281781, 'update_timestamp_ms': 1733561281781, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'YQMDILISTS2X6N2R2SYN3J32', 'name': 'projects/test-project-agb/operations/YQMDILISTS2X6N2R2SYN3J32'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: FAILED
# Export task failed: {'state': 'FAILED', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561281781, 'update_timestamp_ms': 1733561368115, 'start_timestamp_ms': 1733561287308, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'batch_eecu_usage_seconds': 3723.437988281, 'error_message': 'Image.reduceRegions: Computed value is too large.', 'id': 'YQMDILISTS2X6N2R2SYN3J32', 'name': 'projects/test-project-agb/operations/YQMDILISTS2X6N2R2SYN3J32'}
# Lenght of table id 21
# Number of GEDI points: 383318
# Number of first filtered GEDI points: 113282
# Number of 2nd filtered GEDI points: 113282
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561417769, 'update_timestamp_ms': 1733561417769, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'OVAH5DR3I33HRV6NPXMSNXYC', 'name': 'projects/test-project-agb/operations/OVAH5DR3I33HRV6NPXMSNXYC'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 15
# Number of GEDI points: 282679
# Number of first filtered GEDI points: 36979
# Number of 2nd filtered GEDI points: 36979
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561631857, 'update_timestamp_ms': 1733561631857, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'MTIBKVFDCA6DTYJ3LT2KEGXQ', 'name': 'projects/test-project-agb/operations/MTIBKVFDCA6DTYJ3LT2KEGXQ'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 22
# Number of GEDI points: 508439
# Number of first filtered GEDI points: 68851
# Number of 2nd filtered GEDI points: 68851
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733561860486, 'update_timestamp_ms': 1733561860486, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'V4TBG75YTQ5UEH476G6DRSQF', 'name': 'projects/test-project-agb/operations/V4TBG75YTQ5UEH476G6DRSQF'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 27
# Number of GEDI points: 596341
# Number of first filtered GEDI points: 81869
# Number of 2nd filtered GEDI points: 81869
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733562038969, 'update_timestamp_ms': 1733562038969, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'D72XEUEZ22BLAA6HA5UQTMV5', 'name': 'projects/test-project-agb/operations/D72XEUEZ22BLAA6HA5UQTMV5'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 35
# Number of GEDI points: 441323
# Number of first filtered GEDI points: 99048
# Number of 2nd filtered GEDI points: 99048
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733562283095, 'update_timestamp_ms': 1733562283095, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'FE5L6RULQD5EQE5JTOUBVUT7', 'name': 'projects/test-project-agb/operations/FE5L6RULQD5EQE5JTOUBVUT7'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 20
# Number of GEDI points: 349813
# Number of first filtered GEDI points: 39416
# Number of 2nd filtered GEDI points: 39416
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733562501314, 'update_timestamp_ms': 1733562501314, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'V66CZRFWV5ZC2ERG2OOSTSIC', 'name': 'projects/test-project-agb/operations/V66CZRFWV5ZC2ERG2OOSTSIC'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 21
# Number of GEDI points: 482050
# Number of first filtered GEDI points: 61942
# Number of 2nd filtered GEDI points: 61942
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733562756629, 'update_timestamp_ms': 1733562756629, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'WY4ZZRDY7VZ72EISS2TLSUAB', 'name': 'projects/test-project-agb/operations/WY4ZZRDY7VZ72EISS2TLSUAB'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
# Lenght of table id 26
# Number of GEDI points: 551911
# Number of first filtered GEDI points: 15267
# Number of 2nd filtered GEDI points: 15267
# {'state': 'READY', 'description': 'Export_training_data_to_CloudStorage', 'priority': 100, 'creation_timestamp_ms': 1733563497905, 'update_timestamp_ms': 1733563497905, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'B7XD4C5GMYDGUPZU7PH7P6VV', 'name': 'projects/test-project-agb/operations/B7XD4C5GMYDGUPZU7PH7P6VV'}
# Export started
# Current task state: READY
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: RUNNING
# Current task state: COMPLETED
# Export task completed successfully.
